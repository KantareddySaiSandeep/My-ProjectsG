# %%
import pandas as pd

# %%
pd.read_csv('Train Sentiments.csv')
# Out:
#                                            SentenceText SentimentScore  \
# 0     We expect our sales to increase as our new nat...        Postive
# 1     If we turn to our third quarter cost structure...       Negative
# 2     Our performance is built on a company with a s...        Postive
# 3     Our cash flow was strong in the third quarter ...        Postive
# 4      The increase was primarily attributable to an...        Postive
# 5     Through our solid revenue performance, cost in...       Negative
# 6      In every one of our many financial scenarios ...        Postive
# 7     In the third quarter we recorded a $98 million...        Postive
# 8      Your higher funding costs within the average ...       Negative
# 9      So for other revenue we saw an increase of ov...        Postive
# 10    And third, our company has a strong balance sheet        Postive
# 11    As Jeff reported, during the quarter we remain...        Postive
# ...

# %%
from textblob import TextBlob

# %%
train=pd.read_csv()
